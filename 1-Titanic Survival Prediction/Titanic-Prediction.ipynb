# %% [markdown]
# # Importing Libraies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Dataset

# %%
df=pd.read_csv('titanic_train.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass                                  Name   Sex  \
# 0          631         1       1  Barkworth, Mr. Algernon Henry Wilson  male
# 1          852         0       3                   Svensson, Mr. Johan  male
# 2           97         0       1             Goldschmidt, Mr. George B  male
# 3          494         0       1               Artagaveytia, Mr. Ramon  male
# 4          117         0       3                  Connors, Mr. Patrick  male
#
#     Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# 0  80.0      0      0     27042  30.0000   A23        S
# 1  74.0      0      0    347060   7.7750   NaN        S
# 2  71.0      0      0  PC 17754  34.6542    A5        C
# 3  71.0      0      0  PC 17609  49.5042   NaN        C
# 4  70.5      0      0    370369   7.7500   NaN        Q

# %%
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 612          885         0       3
# 195          180         0       3
# 109          340         0       1
# 517          670         1       1
# 847           59         1       2
# 219           21         0       2
# 846          814         0       3
# 358          201         0       3
# 495          569         0       3
# 259          549         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 612                             Sutehall, Mr. Henry Jr    male  25.0      0
# 195                                Leonard, Mr. Lionel    male  36.0      0
# 109                       Blackwell, Mr. Stephen Weart    male  45.0      0
# 517  Taylor, Mrs. Elmer Zebley (Juliet Cummins Wright)  female  28.0      1
# 847                       West, Miss. Constance Mirium  female   5.0      1
# 219                               Fynney, Mr. Joseph J    male  35.0      0
# 846                 Andersson, Miss. Ebba Iris Alfrida  female   6.0      4
# 358                     Vande Walle, Mr. Nestor Cyriel    male  28.0      0
# 495                                Doharr, Mr. Tannous    male  28.0      0
# 259                          Goldsmith, Mr. Frank John    male  33.0      1
#
#      Parch           Ticket     Fare Cabin Embarked
# 612      0  SOTON/OQ 392076   7.0500   NaN        S
# 195      0             LINE   0.0000   NaN        S
# 109      0           113784  35.5000     T        S
# 517      0            19996  52.0000  C126        S
# 847      2       C.A. 34651  27.7500   NaN        S
# 219      0           239865  26.0000   NaN        S
# 846      2           347082  31.2750   NaN        S
# 358      0           345770   9.5000   NaN        S
# 495      0             2686   7.2292   NaN        C
# 259      1           363291  20.5250   NaN        S

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  889.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.348898    0.523008
# std     257.353842    0.486592    0.836071   13.031597    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# # Data Preprocessing

# %%
df=df.drop(columns=['PassengerId','Name','Cabin','Ticket'],axis=1)

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  889.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.348898    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.031597    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
# Checking Data types of All the columns
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
df.nunique()
# Out:
# Survived      2
# Pclass        3
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Fare        248
# Embarked      3
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         2
# SibSp       0
# Parch       0
# Fare        0
# Embarked    2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(2)

# %%
df['Age']=df['Age'].replace(np.nan,df['Age'].median(axis=0))

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Embarked']=df['Embarked'].replace(np.nan,'S')

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age         float64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
df['Age']=df['Age'].astype(int)

# %%
df.dtypes
# Out:
# Survived      int64
# Pclass        int64
# Sex          object
# Age           int64
# SibSp         int64
# Parch         int64
# Fare        float64
# Embarked     object
# dtype: object

# %%
df['Sex'].sample(9)
# Out:
# 773      male
# 689    female
# 705      male
# 427      male
# 561      male
# 650      male
# 697    female
# 616      male
# 480      male
# Name: Sex, dtype: object

# %%
df['Sex']=df['Sex'].apply(lambda x:1 if x=='male' else 0)

# %%
df['Sex'].sample(9)
# Out:
# 403    1
# 6      1
# 535    1
# 41     1
# 30     0
# 400    1
# 737    1
# 333    1
# 0      1
# Name: Sex, dtype: int64

# %%
df['Age'] = pd.cut(
    x=df['Age'],
    bins=[0, 5, 20, 30, 40, 50, 60, 100], 
    labels=['Infant', 'Teen', '20s', '30s', '40s', '50s', 'Elder'],  
    include_lowest=True
)

# %% [markdown]
# # EDA

# %%
# visulizing the count of the features
fig, ax = plt.subplots(2,4,figsize=(20,20))
sns.countplot(x = 'Survived', data = df, ax= ax[0,0])
sns.countplot(x = 'Pclass', data = df, ax=ax[0,1])
sns.countplot(x = 'Sex', data = df, ax=ax[0,2])
sns.countplot(x = 'Age', data = df, ax=ax[0,3])

sns.countplot(x = 'Embarked', data = df, ax=ax[1,0])
sns.histplot(x = 'Fare', data= df, bins=10, ax=ax[1,1])
sns.countplot(x = 'SibSp', data = df, ax=ax[1,2])
sns.countplot(x = 'Parch', data = df, ax=ax[1,3])
# Out:
# <Axes: xlabel='Parch', ylabel='count'>

# %%
sns.countplot(x='Age', data=df,  
              order=df['Age'].value_counts().index[:5])
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
fig, ax = plt.subplots(2,4,figsize=(20,20))
sns.countplot(x = 'Sex', data = df, hue = 'Survived', ax= ax[0,0])
sns.countplot(x = 'Age', data = df, hue = 'Survived', ax=ax[0,1])
sns.boxplot(x = 'Sex',y='Fare', data = df, hue = 'Pclass', ax=ax[0,2])
sns.countplot(x = 'SibSp', data = df, hue = 'Survived', ax=ax[0,3])
sns.countplot(x = 'Parch', data = df, hue = 'Survived', ax=ax[1,0])
sns.scatterplot(x = 'SibSp', y = 'Parch', data = df,hue = 'Survived', ax=ax[1,1])
sns.boxplot(x = 'Embarked', y ='Fare', data = df, ax=ax[1,2])
sns.pointplot(x = 'Pclass', y = 'Survived', data = df, ax=ax[1,3])
fig.show
# Out:
# <bound method Figure.show of <Figure size 2000x2000 with 8 Axes>>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

fig, ax = plt.subplots(2, 4, figsize=(20, 20))

# Countplot for 'Survived'
sns.countplot(x='Survived', data=df, ax=ax[0, 0])
for p in ax[0, 0].patches:  # Loop through bars
    ax[0, 0].text(p.get_x() + p.get_width() / 2,  # X position
                  p.get_height(),  # Y position (top of bar)
                  int(p.get_height()),  # Text (bar height)
                  ha='center', va='bottom', fontsize=12)  # Center alignment

# Countplot for 'Sex'
sns.countplot(x='Sex', data=df, ax=ax[0, 1])
for p in ax[0, 1].patches:
    ax[0, 1].text(p.get_x() + p.get_width() / 2, 
                  p.get_height(), 
                  int(p.get_height()), 
                  ha='center', va='bottom', fontsize=12)

plt.show()
